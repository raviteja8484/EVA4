# %%
# !git clone https://github.com/theschoolofai/YoloV3
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 13.98 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !ls
# Out:
# sample_data  YoloV3

# %%
# %cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !cp '/content/gdrive/My Drive/YoloWeights/yolov3-spp-ultralytics.pt' /content/YoloV3/weights/

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 10 --cache --epochs 25 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=25, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-04-25 10:11:37.065401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 5305.22it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 118.18it/s]
# ...

# %%
# %cd data/
# Out:
# /content/YoloV3/data

# %%
# %rm -rf customdata/

# %%
# %ls
# Out:
# coco.names  customdata/  samples/  smalcoco/

# %%
# !cp -r '/content/gdrive/My Drive/Custom/customdata.zip' /content/YoloV3/data/

# %%
# !unzip -q /content/YoloV3/data/customdata.zip

# %%
# %cd /content/YoloV3
# Out:
# /content/YoloV3

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-spp.cfg --epochs 25 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/customdata/custom.data', device='', epochs=25, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-23 17:23:50.220052: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (347 found, 0 missing, 3 empty, 0 duplicate, for 350 images): 100% 350/350 [00:00<00:00, 9724.86it/s]
# Caching images (0.2GB): 100% 350/350 [00:01<00:00, 348.01it/s]
# ...

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !mkdir Jerry

# %%
# !mkdir /content/Jerry/

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 25 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=25, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-23 18:41:53.922392: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (347 found, 0 missing, 3 empty, 0 duplicate, for 350 images): 100% 350/350 [00:00<00:00, 9471.86it/s]
# Caching images (0.2GB): 100% 350/350 [00:00<00:00, 361.80it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output /content/Jerry/ --source /content/Jerry2.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/Jerry/', save_txt=False, source='/content/Jerry2.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/555) /content/Jerry2.mp4: 320x512 Done. (0.034s)
# video 1/1 (2/555) /content/Jerry2.mp4: 320x512 Done. (0.033s)
# video 1/1 (3/555) /content/Jerry2.mp4: 320x512 Done. (0.025s)
# video 1/1 (4/555) /content/Jerry2.mp4: 320x512 Done. (0.025s)
# video 1/1 (5/555) /content/Jerry2.mp4: 320x512 Done. (0.025s)
# video 1/1 (6/555) /content/Jerry2.mp4: 320x512 Done. (0.025s)
# video 1/1 (7/555) /content/Jerry2.mp4: 320x512 Done. (0.025s)
# video 1/1 (8/555) /content/Jerry2.mp4: 320x512 Done. (0.025s)
# ...

# %%
# !python detect.py --conf-thres 0.3 --output /content/Jerry/ --source /content/Jerry1.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/Jerry/', save_txt=False, source='/content/Jerry1.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/1550) /content/Jerry1.mp4: 320x512 Done. (0.034s)
# video 1/1 (2/1550) /content/Jerry1.mp4: 320x512 Done. (0.028s)
# video 1/1 (3/1550) /content/Jerry1.mp4: 320x512 Done. (0.028s)
# video 1/1 (4/1550) /content/Jerry1.mp4: 320x512 Done. (0.028s)
# video 1/1 (5/1550) /content/Jerry1.mp4: 320x512 Done. (0.028s)
# video 1/1 (6/1550) /content/Jerry1.mp4: 320x512 Done. (0.028s)
# video 1/1 (7/1550) /content/Jerry1.mp4: 320x512 Done. (0.022s)
# ...
