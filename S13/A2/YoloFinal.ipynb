# %%
# !git clone https://github.com/theschoolofai/YoloV3
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 13.95 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !ls
# Out:
# sample_data  YoloV3

# %%
# %cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !cp '/content/gdrive/My Drive/YoloWeights/yolov3-spp-ultralytics.pt' /content/YoloV3/weights/

# %%
# %cd data/
# Out:
# /content/YoloV3/data

# %%
# %rm -rf customdata/

# %%
# %ls
# Out:
# coco.names  samples/  smalcoco/

# %%
# !cp -r '/content/gdrive/My Drive/Custom/customdata.zip' /content/YoloV3/data/

# %%
# !cp /content/yolov3-custom.cfg /content/YoloV3/cfg

# %%
# !unzip -q /content/YoloV3/data/customdata.zip

# %%
# %cd /content/YoloV3
# Out:
# /content/YoloV3

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-26 04:28:12.082406: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25787e+07 parameters, 6.25787e+07 gradients
# Caching labels (696 found, 0 missing, 11 empty, 0 duplicate, for 707 images): 100% 707/707 [00:00<00:00, 10172.49it/s]
# Caching images (0.4GB): 100% 707/707 [00:02<00:00, 300.31it/s]
# Reading image shapes: 100% 707/707 [00:00<00:00, 10672.45it/s]
# ...

# %%
#!cp /content/custom.txt /content/YoloV3/data/customdata/

# %%
#!cp /content/yolov3-custom.cfg /content/YoloV3/cfg/

# %%
# !mkdir /content/TJ

# %%
# !python detect.py --conf-thres 0.1 --output /content/TJ/ --source /content/TJ.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (9579/14575) /content/TJ.mp4: 384x512 Done. (0.067s)
# video 1/1 (9580/14575) /content/TJ.mp4: 384x512 Done. (0.067s)
# video 1/1 (9581/14575) /content/TJ.mp4: 384x512 Done. (0.066s)
# video 1/1 (9582/14575) /content/TJ.mp4: 384x512 Done. (0.067s)
# video 1/1 (9583/14575) /content/TJ.mp4: 384x512 Done. (0.068s)
# video 1/1 (9584/14575) /content/TJ.mp4: 384x512 Done. (0.068s)
# video 1/1 (9585/14575) /content/TJ.mp4: 384x512 Done. (0.068s)
# video 1/1 (9586/14575) /content/TJ.mp4: 384x512 1 Toms, Done. (0.068s)
# video 1/1 (9587/14575) /content/TJ.mp4: 384x512 1 Toms, Done. (0.068s)
# video 1/1 (9588/14575) /content/TJ.mp4: 384x512 1 Toms, Done. (0.067s)
# video 1/1 (9589/14575) /content/TJ.mp4: 384x512 Done. (0.067s)
# video 1/1 (9590/14575) /content/TJ.mp4: 384x512 Done. (0.066s)
# video 1/1 (9591/14575) /content/TJ.mp4: 384x512 Done. (0.066s)
# video 1/1 (9592/14575) /content/TJ.mp4: 384x512 Done. (0.067s)
# ...

# %%
# !cp /content/TJ/TJ.mp4 '/content/gdrive/My Drive/Custom/'
